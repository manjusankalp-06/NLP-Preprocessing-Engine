# %% [markdown]
# # Install library

# %%
# !pip install -U langchain
# Out:
# Requirement already satisfied: langchain in /Applications/anaconda3/lib/python3.13/site-packages (1.2.15)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain) (1.2.28)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Applications/anaconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.23.0)
# Requirement already satisfied: anyio in /Applications/anaconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.7.0)
# Requirement already satisfied: certifi in /Applications/anaconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Applications/anaconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in /Applications/anaconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in /Applications/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Applications/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Applications/anaconda3/lib/python3.13/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.0)

# %% [markdown]
# # Import libraries

# %%
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate

# %% [markdown]
# # Task 1: Replace Hardcoded Prompts

# %%
template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

output = template.format(topic="Artificial Intelligence")
print(output)
# Out:
# Explain Artificial Intelligence in simple terms for beginners

# %% [markdown]
# # Task 2: Multi-Input Prompt System

# %%
multi_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

print(multi_template.format(
    topic="AI",
    audience="beginners",
    tone="friendly"
))

print(multi_template.format(
    topic="Python",
    audience="kids",
    tone="fun"
))

print(multi_template.format(
    topic="Deep Learning",
    audience="engineers",
    tone="technical"
))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %% [markdown]
# # Task 3: Prompt Variations Engine

# %%
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story

# %% [markdown]
# # Task 4: ChatPromptTemplate System

# %%
chat_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful {role}."),
    ("human", "Explain {topic}")
])

messages = chat_template.format_messages(
    role="teacher",
    topic="Neural Networks"
)

for msg in messages:
    print(msg)
# Out:
# content='You are a helpful teacher.' additional_kwargs={} response_metadata={}
# content='Explain Neural Networks' additional_kwargs={} response_metadata={}

# %% [markdown]
# # Task 5: Input Validation Layer

# %%
def validate_inputs(audience, tone):
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]

    if audience not in valid_audience:
        audience = "beginner"

    if tone not in valid_tone:
        tone = "formal"

    return audience, tone


a, t = validate_inputs("beginner", "fun")
print(a, t)
# Out:
# beginner fun

# %% [markdown]
# # Task 6: Prompt Generator App

# %%
def generate_prompt(topic, audience, tone, style):

    audience, tone = validate_inputs(audience, tone)

    style_template = PromptTemplate(
        input_variables=["topic", "audience", "tone", "style"],
        template="Explain {topic} for {audience} in a {tone} {style} style"
    )

    return style_template.format(
        topic=topic,
        audience=audience,
        tone=tone,
        style=style
    )


result = generate_prompt(
    "Neural Networks",
    "beginner",
    "fun",
    "storytelling"
)

print(result)
# Out:
# Explain Neural Networks for beginner in a fun storytelling style

# %% [markdown]
# # Task 7: Template Reusability Test

# %%
reuse_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

topics = [
    "AI",
    "Python",
    "Data Science",
    "NLP",
    "Deep Learning"
]

for t in topics:
    print(reuse_template.format(topic=t))
# Out:
# Explain AI in simple terms
# Explain Python in simple terms
# Explain Data Science in simple terms
# Explain NLP in simple terms
# Explain Deep Learning in simple terms

# %% [markdown]
# # Pipeline Flow

# %%
def pipeline(topic, audience, tone, style):
    return generate_prompt(topic, audience, tone, style)

print(pipeline("Machine Learning", "beginner", "casual", "teaching"))
# Out:
# Explain Machine Learning for beginner in a casual teaching style
